# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aqi=pd.read_csv("aqi.csv")
aqi
# Out:
#               date           state          area  \
# 0       30-04-2025     Maharashtra      Amravati
# 1       30-04-2025           Bihar        Purnia
# 2       30-04-2025  Madhya Pradesh         Katni
# 3       30-04-2025    Chhattisgarh       Tumidih
# 4       30-04-2025           Assam      Byrnihat
# ...            ...             ...           ...
# 235780  01-04-2022           Bihar         Arrah
# 235781  01-04-2022       Rajasthan        Jaipur
# 235782  01-04-2022     Maharashtra    Chandrapur
# 235783  01-04-2022   Uttar Pradesh      Varanasi
# 235784  01-04-2022          Odisha  Brajrajnagar
#
#         number_of_monitoring_stations prominent_pollutants  aqi_value  \
# 0                                   2                 PM10         78
# 1                                   1                   CO         56
# 2                                   1                   O3         98
# 3                                   1                 PM10        103
# ...

# %%
# Step 1: Clean any invisible whitespace (just to be safe)
aqi['date'] = aqi['date'].astype(str).str.strip()

# Step 2: Convert using the exact format
aqi['date'] = pd.to_datetime(aqi['date'], format='%d-%m-%Y', errors='coerce')

# Step 4: Verify a few dates
print(aqi['date'].head())
# Out:
# 0   2025-04-30
# 1   2025-04-30
# 2   2025-04-30
# 3   2025-04-30
# 4   2025-04-30
# Name: date, dtype: datetime64[ns]

# %%
bengaluru_data = aqi[
    (aqi['area'].str.lower() == 'bengaluru') &
    (aqi['date'] >= '2025-03-01') &
    (aqi['date'] <= '2025-05-31')
].copy()

# %%
category_counts = (
    bengaluru_data
    .groupby(['date', 'air_quality_status'])  # Unique days per category
    .size()
    .reset_index(name='count')
)

# %%
summary = (
    category_counts
    .groupby('air_quality_status')
    .size()
    .reset_index(name='number_of_days')
    .sort_values(by='number_of_days', ascending=False)
)

# %%
print(summary)
# Out:
#   air_quality_status  number_of_days
# 1       Satisfactory              48
# 0           Moderate              13

# %%
labels = ['Satisfactory', 'Moderate']
sizes = [48, 13]
colors = ['#66c2a5', '#fc8d62']  # Greenish for good, orange for moderate

plt.figure(figsize=(6, 6))
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    wedgeprops=dict(edgecolor='white')
)

plt.title("Air Quality in Bengaluru (Mar–May 2025)")
plt.axis('equal')  
plt.tight_layout()
plt.show()
